# %%
import pandas as pd

df = pd.read_csv('../data/processed/sale_properties_clustered.csv')

# %%
df.columns
# Out:
# Index(['price_eur', 'barrio_encoded', 'distrito', 'latitude', 'longitude',
#        'adaptado_movilidad_reducida', 'aire_acondicionado', 'antiguedad',
#        'armarios_empotrados', 'ascensor', 'balcon', 'banos', 'calefaccion',
#        'chimenea', 'cocina_equipada', 'conservacion', 'exterior', 'garaje',
#        'habitaciones', 'jardin', 'piscina', 'puerta_blindada',
#        'sistema_seguridad', 'superficie_construida', 'terraza', 'trastero',
#        'vidrios_dobles', 'planta_numerica', 'amueblado_False',
#        'amueblado_True', 'amueblado_nan', 'cluster', 'cluster_label'],
#       dtype='object')

# %%
df2 = pd.read_csv('../data/processed/madrid_sale_properties_processed_1.csv')

# %%
df2["distrito"].isna().sum()
# Out:
# np.int64(1)

# %%
df2
